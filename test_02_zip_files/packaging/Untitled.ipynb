# %%
from get_csv_file import open_zip_csv

# %%
open_zip_csv(80, 2)
# Out:
#                                         QUESTION_TEXT OPTION_1 OPTION_2 OPTION_3
# 0   I know he thought the world of Indy and he was...  control  CONTROL  Control
# 1   I ask him why, and he said he doesn't have tim...  explain  EXPLAIN  Explain
# 2   I was in imminent danger of l _ _ _ _ g my tem...   losing   LOSING   Losing
# 3   He g _ _ _  none of them a chance to speak, th...     gave     GAVE     Gave
# 4   "The tarpaulin was green." Macon Dead r _ _ _ ...   rubbed   RUBBED   Rubbed
# 5   I went bouncing around Times Square like a rac...     come     COME     Come
# 6   "Wait a minute!" Sandy stood erect and her min...  started  STARTED  Started
# 7   Rachel started to get up, and Louis pulled her...      put      PUT      Put
# 8   "Damn." She was doing it to him, and he was le...    stuck    STUCK    Stuck
# 9   He b _ _ _ d low, but did little more than tou...    bowed    BOWED    Bowed
# 10  During training they only jacked you through c...      get      GET      Get
# ...
